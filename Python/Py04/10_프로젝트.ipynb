# %% [markdown]
# <a href="https://colab.research.google.com/github/bett21457-code/AIFFEL_quest_eng/blob/main/Python/Py04/10_%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **사각형의 넓이 구하기**

# %%
# 사각형 넓이를 구하는 클래스 완성!
class Square:
    def __init__(self):
        self.square = int(input('넓이를 구하고 싶은 사각형의 숫자를 써주세요.\n 1.직사각형 2.평행사변형 3.사다리꼴 \n >>>'))

        if self.square == 1:
            print('직사각형 함수는 rect()입니다.')

        elif self.square == 2:
            print('평행사변형 함수는 par()입니다.')

        elif self.square == 3:
            print('사다리꼴 함수는 trape()입니다.')

        else:
            print('1, 2, 3 중에서 다시 입력해주세요')

    def rect(self):
        width, vertical = map(int, input('가로, 세로를 입력하세요. 예시 : 가로,세로\n >>>').split(','))
        area = width * vertical
        result = '직사각형의 넓이는 : ' + str(area)
        return result

    def par(self):
        Base, Height = map(int, input('밑변, 높이를 입력하세요. 예시 : 밑변,높이\n >>>').split(','))
        area1 = Base * Height
        result = '평행사변형의 넓이는 : ' + str(area1)
        return result

    def trape(self):
        UpperBase, Base, Height = map(int, input('윗변, 밑변, 높이를 입력하세요. 예시 : 윗변,밑변,높이\n >>>').split(','))
        area2 = (UpperBase + Base) * Height * 1/2
        result = '사다리꼴의 넓이는 : ' + str(area2)
        return result

a = Square()  # 객체 생성 & 2, 3을 각각 입력해 봅시다.

# %%
a.rect()

# %%
a.par()

# %%
a.trape()

# %% [markdown]
# **키오스크(Kiosk) 만들기 1**

# %%
# 문제 2-3. 주문 메서드

menu = ['americano', 'latte', 'mocha', 'yuza_tea', 'green_tea', 'choco_latte']
price = [2000, 3000, 3000, 2500, 2500, 3000]

class Kiosk:
    def __init__(self):
        # 문제 2-1의 답을 입력하세요.
        self.menu = menu
        self.price = price
        self.order_menu = []  # 주문 리스트 초기화
        self.order_price = [] # 가격 리스트 초기화

    # 메뉴 출력 메서드
    def menu_print(self):
        for i in range(len(self.menu)):
            print(i + 1, self.menu[i], ' : ', self.price[i], '원')

    # 주문 메서드
    def menu_select(self):
        print()  # 줄 바꿈
        n = 0
        while n < 1 or len(self.menu) < n:
            n = int(input("음료 번호를 입력하세요 : "))  # 음료 번호 입력

            # 메뉴판에 있는 음료 번호일때
            if 1 <= n and n <= len(self.menu): # Changed & to and, and used self.menu
                pass # The variable self.price_sum was not used, so it's removed.

            # 메뉴판에 없는 번호일 때
            else:
                print("없는 메뉴입니다. 다시 주문해 주세요.")

        # 음료 온도 물어보기
        t = 0  # 기본값을 넣어주고
        while t != 1 and t != 2:  # 1이나 2를 입력할 때까지 물어보기
            t= int(input("HOT 음료는 1을, ICE 음료는 2를 입력하세요 : "))
            # 문제 2-3. 음료의 온도에 따라 temp 변수를 "HOT" 또는 "ICE"로 지정하세요.
            # 힌트: if문을 활용해보세요.
            if t == 1:
               self.temp = "HOT"
            elif t == 2:
                self.temp = "ICE"
            else:
                print("1과 2 중 하나를 입력하세요.\n")

        self.order_price.append(self.price[n-1])  # 가격 리스트에 추가
        self.order_menu.append(self.temp + ' ' + self.menu[n-1])  # 주문 리스트에 추가
        print(self.order_menu, self.order_price)
        print('주문 음료', self.temp, self.menu[n-1], ' : ', self.price[n-1], '원')  # 온도 속성을 추가한 주문 결과 출력

# %%
# 아이스 초코라떼 주문해보기
a = Kiosk()  # 객체 생성
a.menu_print()  # 메뉴 출력
a.menu_select()
# Out:
# 1 americano  :  2000 원
# 2 latte  :  3000 원
# 3 mocha  :  3000 원
# 4 yuza_tea  :  2500 원
# 5 green_tea  :  2500 원
# 6 choco_latte  :  3000 원
#
# 음료 번호를 입력하세요 : 1
# HOT 음료는 1을, ICE 음료는 2를 입력하세요 : 2
# ['ICE americano'] [2000]
# 주문 음료 ICE americano  :  2000 원

# %% [markdown]
# **키오스크(Kiosk) 만들기 2**

# %%
# 3. 지불 메서드
def pay(self):
        total_sum = sum(self.order_price)
        print(f"\n지불할 총 금액은 {total_sum}원입니다.")

        while True:
            choice = input("지불 수단을 선택하세요 (1. 현금 / 2. 카드): ").strip().lower()

            if choice in ['1', 'cash']:
                print("직원을 호출하겠습니다.")
                break
            elif choice in ['2', 'card']:
                print("IC칩 방향에 맞게 카드를 꽂아주세요.")
                break
            else:
                print("다시 결제를 시도해 주세요.")

# %%
# 4. 주문서(영수증) 출력 메서드
class Kiosk:
    def __init__(self):
        self.menu = ['americano', 'latte', 'mocha', 'yuza_tea', 'green_tea', 'choco_latte']
        self.price = [2000, 3000, 3000, 2500, 2500, 3000]
        self.order_menu = []
        self.order_price = []

    # (중략: menu_print, menu_select, pay 메서드는 이전과 동일)

    def table(self):
        # 외곽 상단
        print('\n' + '⟝' + '-' * 30 + '⟞')
        for _ in range(3):
            print('|' + ' ' * 31 + '|')

        # 주문 상품명 및 금액 출력
        for i in range(len(self.order_menu)):
            # 한글이 포함된 경우 ljust가 예상과 다를 수 있어, 수동으로 간격을 맞추거나
            # 단순하게 출력하여 구조를 확인합니다.
            item = f"{self.order_menu[i]} : {self.order_price[i]}원"
            print(f"| {item}") # 여기서는 간단하게 시작 지점만 맞춥니다.

        # 합계 금액 계산
        total_sum = sum(self.order_price)

        print(f"| {'-'*29} |")
        print(f"| 합계 금액 : {total_sum}원")

        # 외곽 하단
        for _ in range(3):
            print('|' + ' ' * 31 + '|')
        print('⟝' + '-' * 30 + '⟞')

# %%
a = Kiosk()  # 객체 생성
a.menu_print()  # 메뉴 출력
a.menu_select()  # 주문
a.pay()  # 지불
a.table()  # 주문표 출력
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1416/1973815409.py in <cell line: 0>()
#       1 a = Kiosk()  # 객체 생성
# ----> 2 a.menu_print()  # 메뉴 출력
#       3 a.menu_select()  # 주문
#       4 a.pay()  # 지불
#       5 a.table()  # 주문표 출력
#
# AttributeError: 'Kiosk' object has no attribute 'menu_print'
